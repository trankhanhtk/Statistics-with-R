# %%
T = matrix(c(0, 1, -1, 0), ncol=2)
cat('T:')
T
C = matrix(c(2, 1, -1, 1), ncol=2)
cat('C:')
C
# Out:
# T:
#      [,1] [,2]
# [1,] 0    -1
# [2,] 1     0
# C:
#      [,1] [,2]
# [1,] 2    -1
# [2,] 1     1

# %%
C_inv = solve(C)
cat('C_inv:')
C_inv
# Out:
# C_inv:
#      [,1]       [,2]
# [1,]  0.3333333 0.3333333
# [2,] -0.3333333 0.6666667

# %%
x = matrix(c(-2, 1), ncol=1)
x
# Out:
#      [,1]
# [1,] -2
# [2,]  1

# %%
cat('Test:')
matrix(c(1/3, 5/3, -2/3, -1/3), ncol=2)
# Out:
# Test:
#      [,1]      [,2]
# [1,] 0.3333333 -0.6666667
# [2,] 1.6666667 -0.3333333

# %%
E = C_inv %*% T %*% C
E
# Out:
#      [,1]      [,2]
# [1,] 0.3333333 -0.6666667
# [2,] 1.6666667 -0.3333333

# %%
x = matrix(c(1, 2), ncol=1)

# %%
E %*% x
# Out:
#      [,1]
# [1,] -1
# [2,]  1

# %%
T %*% x
# Out:
#      [,1]
# [1,] -2
# [2,]  1

# %%
X = matrix(runif(50, 1, 100), ncol=5)
X
# Out:
#       [,1]      [,2]     [,3]      [,4]      [,5]
#  [1,] 93.477062 86.89855 90.171442 22.760090 82.93577
#  [2,]  8.793013 57.84733 73.333217 14.300624 36.29917
#  [3,] 28.861981 20.97474 62.598452 39.933101 94.56844
#  [4,] 37.115927 47.62633  1.800705 17.407926 35.71894
#  [5,] 10.857493 88.45113 35.649175 13.514977 77.95478
#  [6,] 48.211314 59.56649 46.864642 80.971794 34.60597
#  [7,] 47.247817 49.77589 47.216698  7.182217 55.52035
#  [8,] 11.081803 68.31590  3.373144 20.700487 97.50464
#  [9,] 34.577265 15.03016 77.220920 31.995933 39.55031
# [10,] 35.003173 50.29348 82.812328 63.885780 72.78211

# %%
X %*% solve(t(X)  %*% X)  %*% t(X)
# Out:
#       [,1]        [,2]        [,3]        [,4]        [,5]        [,6]
#  [1,]  0.72913190 -0.02000983  0.10846128 -0.23914342  0.04873498  0.04835247
#  [2,] -0.02000983  0.29011300  0.16251899  0.29795501  0.21474103  0.13340034
#  [3,]  0.10846128  0.16251899  0.13571975  0.12898763  0.06458573  0.08089075
#  [4,] -0.23914342  0.29795501  0.12898763  0.39555430  0.13000934  0.14145238
#  [5,]  0.04873498  0.21474103  0.06458573  0.13000934  0.59174957  0.07264217
#  [6,]  0.04835247  0.13340034  0.08089075  0.14145238  0.07264217  0.28658849
#  [7,]  0.21350472  0.08652597  0.17473888  0.02521679 -0.16046310  0.22655123
#  [8,] -0.05567222 -0.02350894 -0.06666562  0.10863001 -0.24642090  0.23831674
#  [9,]  0.08343781 -0.09494146 -0.12262571 -0.14315874  0.28231302  0.18339348
# [10,]  0.26035777  0.09692671  0.04190639  0.08151397  0.02388030 -0.10363129
#       [,7]        [,8]        [,9]        [,10]
#  [1,]  0.21350472 -0.05567222  0.08343781  0.26035777
# ...

# %%
t(X) %*% X
# Out:
#      [,1]     [,2]     [,3]     [,4]     [,5]
# [1,] 18244.07 20225.88 21430.85 12013.73 22260.63
# [2,] 20225.88 34877.69 27327.67 15955.97 35627.67
# [3,] 21430.85 27327.67 35959.36 18078.86 32557.10
# [4,] 12013.73 15955.97 18078.86 14944.53 18992.94
# [5,] 22260.63 35627.67 32557.10 18992.94 45140.65

# %%
round(solve(t(X) %*% X), 8)
# Out:
#      [,1]        [,2]        [,3]        [,4]        [,5]
# [1,]  0.00023306 -0.00006790 -0.00008177 -0.00002780  0.00000933
# [2,] -0.00006790  0.00017324  0.00000766 -0.00000303 -0.00010750
# [3,] -0.00008177  0.00000766  0.00013329 -0.00005390 -0.00003918
# [4,] -0.00002780 -0.00000303 -0.00005390  0.00018878 -0.00002445
# [5,]  0.00000933 -0.00010750 -0.00003918 -0.00002445  0.00014094
